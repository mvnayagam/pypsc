# %% [markdown]
# # Example to solve structures within EPA framework

# %%
import logging
from psc.config.logconfig import setup_logging
# import uuid
import numpy as np

from psc.lib.pscsolver import PSCSolver

# ------ USAGE
solver = PSCSolver(reflections=np.arange(1,5), structurefactor=[1, 1, 1], structure=[0.328,0.218, 0.125], intensity_type='intensity', write_polytope=True)
result = solver.solve()
result

# %% [markdown]
# # Plot result from HDF file

# %%
from psc.lib.solutionreader import SolutionReader
from psc.utils.plothdf import Plotting
from pathlib import Path

file="YOUR FILE NAME" # ex. "pscsolver_20260627-172909-c15eca.h5"
datafile = SolutionReader(str(Path(file)))
plot = Plotting(datafile)
# plot.report()
plot.plot_dual_convergence()
# plot.plot_convergence_metric()
# plot.plot_per_level_timing()
# plot.plot_scalar_timing()
# plot.plot_intersector_timing()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from psc.lib.solutionreader import SolutionReader
#       2 from psc.utils.plothdf import Plotting
#       4 # Usage
#
# ModuleNotFoundError: No module named 'psc'
